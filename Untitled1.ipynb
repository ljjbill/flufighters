# %%
# Dependencies
import pandas as pd
# reading monthly mean
death = "Deaths.csv"

# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
death_df = pd.read_csv(death, encoding="ISO-8859-1")
final_state=death_df.rename(columns={'State':'state_name'})
##death_state_groups = final_state.groupby("state_name")

final_df=final_state.query('state_name != ')
final_df
# Show just monthlumean header
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     180             if self.has_resolvers:
# --> 181                 return self.resolvers[key]
#     182
#
# ~\Anaconda3\lib\collections\__init__.py in __getitem__(self, key)
#     913                 pass
# --> 914         return self.__missing__(key)            # support subclasses that define __missing__
#     915
#
# ~\Anaconda3\lib\collections\__init__.py in __missing__(self, key)
#     905     def __missing__(self, key):
# --> 906         raise KeyError(key)
#     907
#
# KeyError: 'NaN'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
death_df.to_csv("death_state_group_v1.csv", index=False, header=True)
