# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load
weather_data_to_load = "monthly_mean_temps.csv"
state_data_to_load = "State_Names.csv"

# Read the weahter and state Data
weather_df = pd.read_csv(weather_data_to_load, low_memory=False)
state_df = pd.read_csv(state_data_to_load, low_memory=False)

# %%
weather_df.head()
# Out:
#             City State  January  February  March  April   May  June  July  \
# 0  BIRMINGHAM AP    AL     43.8      47.7   55.2   62.5  70.6  77.7  81.1
# 1     HUNTSVILLE    AL     41.5      45.7   53.5   61.8  70.3  77.7  80.6
# 2         MOBILE    AL     50.2      53.5   59.8   66.4  73.8  79.8  82.1
# 3     MONTGOMERY    AL     46.6      50.5   57.5   64.1  72.4  79.0  81.8
# 4      ANCHORAGE    AK     17.1      20.2   26.6   36.8  47.8  55.2  58.8
#
#    August  September  October  November  December  Annual
# 0    80.7       74.7     64.1      54.4      46.1    63.2
# 1    80.1       73.7     62.8      52.7      43.9    62.0
# 2    82.1       78.5     69.2      60.0      52.6    67.3
# 3    81.5       76.3     65.9      56.5      48.5    65.1
# 4    56.7       48.6     34.8      22.2      19.0    37.0

# %%
state_df.head()
# Out:
#   US State Name State Code
# 0       Alabama         AL
# 1        Alaska         AK
# 2       Arizona         AZ
# 3      Arkansas         AR
# 4    California         CA

# %%
# Combine the data into a single dataset to get the full name of each state
merge_table = pd.merge(weather_df, state_df, left_on="State",right_on="State Code", how="left")
merge_table
# Out:
#                        City State  January  February  March  April   May  \
# 0             BIRMINGHAM AP    AL     43.8      47.7   55.2   62.5  70.6
# 1                HUNTSVILLE    AL     41.5      45.7   53.5   61.8  70.3
# 2                    MOBILE    AL     50.2      53.5   59.8   66.4  73.8
# 3                MONTGOMERY    AL     46.6      50.5   57.5   64.1  72.4
# 4                 ANCHORAGE    AK     17.1      20.2   26.6   36.8  47.8
# 5                   ANNETTE    AK     37.0      37.7   39.7   44.2  50.2
# 6                    BARROW    AK    -13.4     -14.2  -12.7    1.8  21.1
# 7                    BETHEL    AK      6.6      11.1   15.2   26.9  41.9
# 8                   BETTLES    AK    -10.0      -5.0    4.4   23.3  44.4
# 9                 BIG DELTA    AK     -1.0       4.9   14.1   32.2  47.6
# 10                 COLD BAY    AK     28.2      29.0   30.1   34.0  40.3
# 11                FAIRBANKS    AK     -7.9      -1.3   11.4   32.5  49.4
# ...

# %%
# group by state
grouped_df =merge_table.groupby(['US State Name','State'])
grouped_df
# set a blank list to contain monthly data later
frames=[]

for month in ["January","February","March","April","May","June","July","August","September","October","November","December"]:
    temp=grouped_df[month].mean()
    monthly_data = pd.DataFrame({
    "Month": month,
    "Avg_temp": temp})
    frames.append(monthly_data)

# consolidate all monthly data in frames list 
main_table = pd.concat(frames)
main_table
# Out:
#                          Month   Avg_temp
# US State Name  State
# Alabama        AL      January  45.525000
# Alaska         AK      January  11.930000
# Arizona        AZ      January  45.960000
# Arkansas       AR      January  40.433333
# California     CA      January  49.237500
# Colorado       CO      January  27.080000
# Connecticut    CT      January  28.600000
# Delaware       DE      January  32.400000
# Florida        FL      January  59.276923
# Georgia        GA      January  46.100000
# Hawaii         HI      January  71.225000
# Idaho          ID      January  30.400000
# Illinois       IL      January  23.900000
# Indiana        IN      January  27.475000
# Iowa           IA      January  19.650000
# Kansas         KS      January  30.460000
# Kentucky       KY      January  34.225000
# Louisiana      LA      January  50.825000
# Maine          ME      January  16.250000
# Maryland       MD      January  32.900000
# Massachusetts  MA      January  26.200000
# ...

# %%
main_table.to_csv("Resources/weather_data.csv", index=True, header=True)
