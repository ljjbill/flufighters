# %%
# Import Dependencies
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.pyplot import figure

# %%
# File to Load
Data_to_load = "Resources/final_data.csv"
flufighter_df = pd.read_csv(Data_to_load, low_memory=False,thousands=',')
flufighter_df.head()
# Out:
#    Unnamed: 0 US State Name State_x   State_x.1  Month_x   Avg_temp  \
# 0           0       Alabama      AL     Alabama  January  45.525000
# 1           1        Alaska      AK      Alaska  January  11.930000
# 2           2       Arizona      AZ     Arizona  January  45.960000
# 3           3      Arkansas      AR    Arkansas  January  40.433333
# 4           4    California      CA  California  January  49.237500
#
#    Density (Pop./ mi2)  Population  sick death    all death  Children 0-18  \
# 0                 95.0     4858979   93.255814  1081.883721           0.24
# 1                  1.0      738432    4.813953    82.255814           0.27
# 2                 60.0     6828065   90.232558  1099.395349           0.25
# 3                 57.0     2978204   67.418605   660.209302           0.25
# 4                251.0    39144818  612.139535  5480.674419           0.24
#
#    Adults 19-25  Adults 26-34  Adults 35-54  Adults 55-64   65+  \
# 0          0.09          0.11          0.26          0.14  0.17
# 1          0.09          0.14          0.26          0.13  0.11
# 2          0.09          0.12          0.25          0.12  0.17
# 3          0.09          0.11          0.25          0.13  0.17
# 4          0.10          0.14          0.27          0.12  0.14
#
#    Sick_death_rate(in 1000 people_wkly)  All_death_rate(in 1000 people_wkly)  \
# 0                              0.019192                             0.222657
# 1                              0.006519                             0.111393
# 2                              0.013215                             0.161011
# 3                              0.022637                             0.221680
# 4                              0.015638                             0.140010
#
#    sick of all death  GDP per capita
# 0           0.086198           36404
# 1           0.058524           69326
# 2           0.082075           38340
# 3           0.102117           35412
# 4           0.111691           54232

# %%
# convert GDP data to numeric
pd.to_numeric(flufighter_df['GDP per capita'])
# group by state
grouped_df =flufighter_df.groupby(['US State Name'])
grouped_df

# %%
# define datapoints
GDP=grouped_df["GDP per capita"].mean()
avg_sick_death=grouped_df["Sick_death_rate(in 1000 people_wkly)"].mean()*52
avg_all_death=grouped_df["All_death_rate(in 1000 people_wkly)"].mean()*52
old_percent=grouped_df["65+"].mean()
young_percent=grouped_df["Adults 26-34"].mean()

# %%
Viz_data=pd.DataFrame({
    "GDP per capita": GDP,
    "Annual Sickness Mortality (per thousand people)": avg_sick_death,
"Annual Overall Mortality (per thousand people)": avg_all_death,
"Age 65+ % of total":old_percent,
"Age 26-34 % of total":young_percent})
Viz_data.head()
# Out:
#                GDP per capita  \
# US State Name
# Alabama                 36404
# Alaska                  69326
# Arizona                 38340
# Arkansas                35412
# California              54232
#
#                Annual Sickness Mortality (per thousand people)  \
# US State Name
# Alabama                                               0.668389
# Alaska                                                0.328839
# Arizona                                               0.485091
# Arkansas                                              0.812139
# California                                            0.552163
#
#                Annual Overall Mortality (per thousand people)  \
# US State Name
# Alabama                                             10.395454
# Alaska                                               5.529722
# Arizona                                              7.647022
# Arkansas                                            10.277937
# California                                           6.400295
#
#                Age 65+ % of total  Age 26-34 % of total
# US State Name
# Alabama                      0.17                  0.11
# Alaska                       0.11                  0.14
# Arizona                      0.17                  0.12
# Arkansas                     0.17                  0.11
# California                   0.14                  0.14

# %%
Viz_data.plot(kind="scatter", x="GDP per capita", y="Annual Sickness Mortality (per thousand people)", grid=True, figsize=(10,10),
              title="Sickness Morality vs. GDP per capita")

plt.ylim(0, 1)
plt.xlim(25000, 70000)


# calc the trendline
z = np.polyfit(Viz_data["GDP per capita"], Viz_data["Annual Sickness Mortality (per thousand people)"], 1)
p = np.poly1d(z)
plt.plot(Viz_data["GDP per capita"],p(Viz_data["GDP per capita"]),"red")
plt.savefig('Resources/Images/sickness mortality GDP.png')
plt.show()

# %%
Viz_data.plot(kind="scatter", x="GDP per capita", y="Annual Overall Mortality (per thousand people)", grid=True, figsize=(10,10),
              title="Overall Mortality vs. GDP per capita")

plt.ylim(0, 15)
plt.xlim(25000, 70000)


# calc the trendline
z = np.polyfit(Viz_data["GDP per capita"], Viz_data["Annual Overall Mortality (per thousand people)"], 1)
p = np.poly1d(z)
plt.plot(Viz_data["GDP per capita"],p(Viz_data["GDP per capita"]),"red")
plt.savefig('Resources/Images/overall mortality GDP.png')
plt.show()

# %%
Viz_data.plot(kind="scatter", x="Age 65+ % of total", y="Annual Sickness Mortality (per thousand people)", grid=True, figsize=(10,10),
              title="Sickness Morality vs. People over 65")

plt.ylim(0, 1)
plt.xlim(0,0.25)


# calc the trendline
z = np.polyfit(Viz_data["Age 65+ % of total"], Viz_data["Annual Sickness Mortality (per thousand people)"], 1)
p = np.poly1d(z)
plt.plot(Viz_data["Age 65+ % of total"],p(Viz_data["Age 65+ % of total"]),"red")
plt.savefig('Resources/Images/sickness mortality old.png')
plt.show()

# %%
Viz_data.plot(kind="scatter", x="Age 26-34 % of total", y="Annual Sickness Mortality (per thousand people)", grid=True, figsize=(10,10),
              title="Sickness Morality vs. People age 26 -34")

plt.ylim(0, 1)
plt.xlim(0.05,0.15)


# calc the trendline
z = np.polyfit(Viz_data["Age 26-34 % of total"], Viz_data["Annual Sickness Mortality (per thousand people)"], 1)
p = np.poly1d(z)
plt.plot(Viz_data["Age 26-34 % of total"],p(Viz_data["Age 26-34 % of total"]),"red")
plt.savefig('Resources/Images/sickness mortality young.png')
plt.show()
